# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiJain456/compute/blob/main/football.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
p1 = '/content/drive/MyDrive/countries.csv'
p2 = '/content/drive/MyDrive/leagues.csv'
p3 = '/content/drive/MyDrive/teams.csv'
p4 = '/content/drive/MyDrive/matches.csv'
p5 = '/content/drive/MyDrive/player.csv'

# %%
cou = pd.read_csv(p1)
lea = pd.read_csv(p2)
team = pd.read_csv(p3)
mat = pd.read_csv(p4)
ply = pd.read_csv(p5)

# %%
mat.columns #list of all columns
# Out:
# Index(['Unnamed: 0', 'id', 'country_id', 'league_id', 'season', 'stage',
#        'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id',
#        ...
#        'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH', 'BSD', 'BSA'],
#       dtype='object', length=116)

# %%
#dropping unnecessary columns
mat.drop(mat.columns[[0,5,6]], axis=1, inplace = True)
mat.drop(mat.columns[12:116], axis=1, inplace = True)

# %%
mat.head(10)
# Out:
#    id  country_id  league_id     season  match_api_id  home_team_api_id  \
# 0   1           1          1  2008/2009        492473              9987
# 1   2           1          1  2008/2009        492474             10000
# 2   3           1          1  2008/2009        492475              9984
# 3   4           1          1  2008/2009        492476              9991
# 4   5           1          1  2008/2009        492477              7947
# 5   6           1          1  2008/2009        492478              8203
# 6   7           1          1  2008/2009        492479              9999
# 7   8           1          1  2008/2009        492480              4049
# 8   9           1          1  2008/2009        492481             10001
# 9  10           1          1  2008/2009        492564              8342
#
#    away_team_api_id  home_team_goal  away_team_goal  home_player_X1  \
# 0              9993               1               1             NaN
# 1              9994               0               0             NaN
# 2              8635               0               3             NaN
# 3              9998               5               0             NaN
# 4              9985               1               3             NaN
# 5              8342               1               1             NaN
# 6              8571               2               2             NaN
# 7              9996               1               2             NaN
# 8              9986               1               0             NaN
# 9              8571               4               1             NaN
#
#    home_player_X2  home_player_X3
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# 5             NaN             NaN
# 6             NaN             NaN
# 7             NaN             NaN
# 8             NaN             NaN
# 9             NaN             NaN

# %%
cou.drop(cou[["Unnamed: 0"]],axis = 1, inplace = True)
cou.head()
# Out:
#       id     name
# 0      1  Belgium
# 1   1729  England
# 2   4769   France
# 3   7809  Germany
# 4  10257    Italy

# %%
lea.drop(lea[["Unnamed: 0"]],axis = 1, inplace = True)
lea.head()
# Out:
#       id  country_id                    name   id.1   name.1
# 0      1           1  Belgium Jupiler League      1  Belgium
# 1   1729        1729  England Premier League   1729  England
# 2   4769        4769          France Ligue 1   4769   France
# 3   7809        7809   Germany 1. Bundesliga   7809  Germany
# 4  10257       10257           Italy Serie A  10257    Italy

# %%
lea.rename(columns = {"name" : "league", 'name.1':'country'}, inplace = True)
lea
# Out:
#        id  country_id                    league   id.1      country
# 0       1           1    Belgium Jupiler League      1      Belgium
# 1    1729        1729    England Premier League   1729      England
# 2    4769        4769            France Ligue 1   4769       France
# 3    7809        7809     Germany 1. Bundesliga   7809      Germany
# 4   10257       10257             Italy Serie A  10257        Italy
# 5   13274       13274    Netherlands Eredivisie  13274  Netherlands
# 6   15722       15722        Poland Ekstraklasa  15722       Poland
# 7   17642       17642  Portugal Liga ZON Sagres  17642     Portugal
# 8   19694       19694   Scotland Premier League  19694     Scotland
# 9   21518       21518           Spain LIGA BBVA  21518        Spain
# 10  24558       24558  Switzerland Super League  24558  Switzerland

# %%
df = pd.merge(left = lea, right = mat , how = 'left', left_on = 'country_id', right_on ='country_id')
df
# Out:
#         id_x  country_id                    league   id.1      country   id_y  \
# 0          1           1    Belgium Jupiler League      1      Belgium      1
# 1          1           1    Belgium Jupiler League      1      Belgium      2
# 2          1           1    Belgium Jupiler League      1      Belgium      3
# 3          1           1    Belgium Jupiler League      1      Belgium      4
# 4          1           1    Belgium Jupiler League      1      Belgium      5
# ...      ...         ...                       ...    ...          ...    ...
# 25974  24558       24558  Switzerland Super League  24558  Switzerland  25975
# 25975  24558       24558  Switzerland Super League  24558  Switzerland  25976
# 25976  24558       24558  Switzerland Super League  24558  Switzerland  25977
# 25977  24558       24558  Switzerland Super League  24558  Switzerland  25978
# 25978  24558       24558  Switzerland Super League  24558  Switzerland  25979
#
#        league_id     season  match_api_id  home_team_api_id  away_team_api_id  \
# 0              1  2008/2009        492473              9987              9993
# 1              1  2008/2009        492474             10000              9994
# 2              1  2008/2009        492475              9984              8635
# 3              1  2008/2009        492476              9991              9998
# 4              1  2008/2009        492477              7947              9985
# ...          ...        ...           ...               ...               ...
# 25974      24558  2015/2016       1992091             10190             10191
# 25975      24558  2015/2016       1992092              9824             10199
# 25976      24558  2015/2016       1992093              9956             10179
# 25977      24558  2015/2016       1992094              7896             10243
# 25978      24558  2015/2016       1992095             10192              9931
#
#        home_team_goal  away_team_goal  home_player_X1  home_player_X2  \
# 0                   1               1             NaN             NaN
# 1                   0               0             NaN             NaN
# 2                   0               3             NaN             NaN
# 3                   5               0             NaN             NaN
# 4                   1               3             NaN             NaN
# ...               ...             ...             ...             ...
# 25974               1               0             1.0             2.0
# 25975               1               2             1.0             3.0
# 25976               2               0             1.0             2.0
# 25977               0               0             1.0             2.0
# 25978               4               3             1.0             2.0
#
#        home_player_X3
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 25974             4.0
# 25975             5.0
# 25976             4.0
# 25977             4.0
# 25978             4.0
#
# [25979 rows x 16 columns]

# %%
df.drop(df[['league_id','id.1']], axis = 1, inplace = True)
df
# Out:
#         id_x  country_id                    league      country   id_y  \
# 0          1           1    Belgium Jupiler League      Belgium      1
# 1          1           1    Belgium Jupiler League      Belgium      2
# 2          1           1    Belgium Jupiler League      Belgium      3
# 3          1           1    Belgium Jupiler League      Belgium      4
# 4          1           1    Belgium Jupiler League      Belgium      5
# ...      ...         ...                       ...          ...    ...
# 25974  24558       24558  Switzerland Super League  Switzerland  25975
# 25975  24558       24558  Switzerland Super League  Switzerland  25976
# 25976  24558       24558  Switzerland Super League  Switzerland  25977
# 25977  24558       24558  Switzerland Super League  Switzerland  25978
# 25978  24558       24558  Switzerland Super League  Switzerland  25979
#
#           season  match_api_id  home_team_api_id  away_team_api_id  \
# 0      2008/2009        492473              9987              9993
# 1      2008/2009        492474             10000              9994
# 2      2008/2009        492475              9984              8635
# 3      2008/2009        492476              9991              9998
# 4      2008/2009        492477              7947              9985
# ...          ...           ...               ...               ...
# 25974  2015/2016       1992091             10190             10191
# 25975  2015/2016       1992092              9824             10199
# 25976  2015/2016       1992093              9956             10179
# 25977  2015/2016       1992094              7896             10243
# 25978  2015/2016       1992095             10192              9931
#
#        home_team_goal  away_team_goal  home_player_X1  home_player_X2  \
# 0                   1               1             NaN             NaN
# 1                   0               0             NaN             NaN
# 2                   0               3             NaN             NaN
# 3                   5               0             NaN             NaN
# 4                   1               3             NaN             NaN
# ...               ...             ...             ...             ...
# 25974               1               0             1.0             2.0
# 25975               1               2             1.0             3.0
# 25976               2               0             1.0             2.0
# 25977               0               0             1.0             2.0
# 25978               4               3             1.0             2.0
#
#        home_player_X3
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 25974             4.0
# 25975             5.0
# 25976             4.0
# 25977             4.0
# 25978             4.0
#
# [25979 rows x 14 columns]

# %%
df.drop(df[["country_id"]],axis =1, inplace = True)

# %%
team_att = pd.read_csv('/content/drive/MyDrive/team_attributes.csv')
team_att
# Out:
#       Unnamed: 0    id  team_fifa_api_id  team_api_id                 date  \
# 0              0     1               434         9930  2010-02-22 00:00:00
# 1              1     2               434         9930  2014-09-19 00:00:00
# 2              2     3               434         9930  2015-09-10 00:00:00
# 3              3     4                77         8485  2010-02-22 00:00:00
# 4              4     5                77         8485  2011-02-22 00:00:00
# ...          ...   ...               ...          ...                  ...
# 1453        1453  1454             15005        10000  2011-02-22 00:00:00
# 1454        1454  1455             15005        10000  2012-02-22 00:00:00
# 1455        1455  1456             15005        10000  2013-09-20 00:00:00
# 1456        1456  1457             15005        10000  2014-09-19 00:00:00
# 1457        1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# 2                   47              Balanced                  41.0
# 3                   70                  Fast                   NaN
# 4                   47              Balanced                   NaN
# ...                ...                   ...                   ...
# 1453                52              Balanced                   NaN
# 1454                54              Balanced                   NaN
# 1455                54              Balanced                   NaN
# 1456                54              Balanced                  42.0
# 1457                54              Balanced                  42.0
#
#      buildUpPlayDribblingClass  buildUpPlayPassing  ...  \
# 0                       Little                  50  ...
# 1                       Normal                  56  ...
# 2                       Normal                  54  ...
# 3                       Little                  70  ...
# 4                       Little                  52  ...
# ...                        ...                 ...  ...
# 1453                    Little                  52  ...
# 1454                    Little                  51  ...
# 1455                    Little                  51  ...
# 1456                    Normal                  51  ...
# 1457                    Normal                  51  ...
#
#      chanceCreationShooting chanceCreationShootingClass  \
# 0                        55                      Normal
# 1                        64                      Normal
# 2                        64                      Normal
# 3                        70                        Lots
# 4                        52                      Normal
# ...                     ...                         ...
# 1453                     53                      Normal
# 1454                     50                      Normal
# 1455                     32                      Little
# 1456                     32                      Little
# 1457                     32                      Little
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              50                Medium
# 1                          Organised              47                Medium
# 2                          Organised              47                Medium
# 3                          Organised              60                Medium
# 4                          Organised              47                Medium
# ...                              ...             ...                   ...
# 1453                       Organised              46                Medium
# 1454                       Organised              44                Medium
# 1455                       Organised              44                Medium
# 1456                       Organised              44                Medium
# 1457                       Organised              44                Medium
#
#      defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                   55                   Press               45
# 1                   44                   Press               54
# 2                   44                   Press               54
# 3                   70                  Double               70
# 4                   47                   Press               52
# ...                ...                     ...              ...
# 1453                48                   Press               53
# 1454                55                   Press               53
# 1455                58                   Press               37
# 1456                58                   Press               37
# 1457                58                   Press               37
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                   Normal                     Cover
# 1                   Normal                     Cover
# 2                   Normal                     Cover
# 3                     Wide                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1453                Normal                     Cover
# 1454                Normal                     Cover
# 1455                Normal                     Cover
# 1456                Normal                     Cover
# 1457                Normal                     Cover
#
# [1458 rows x 26 columns]

# %%
team
# Out:
#      Unnamed: 0     id  team_api_id  team_fifa_api_id      team_long_name  \
# 0             0      1         9987             673.0            KRC Genk
# 1             1      2         9993             675.0        Beerschot AC
# 2             2      3        10000           15005.0    SV Zulte-Waregem
# 3             3      4         9994            2007.0    Sporting Lokeren
# 4             4      5         9984            1750.0   KSV Cercle Brugge
# ..          ...    ...          ...               ...                 ...
# 294         294  49479        10190             898.0       FC St. Gallen
# 295         295  49837        10191            1715.0             FC Thun
# 296         296  50201         9777             324.0         Servette FC
# 297         297  50204         7730            1862.0  FC Lausanne-Sports
# 298         298  51606         7896               NaN              Lugano
#
#     team_short_name
# 0               GEN
# 1               BAC
# 2               ZUL
# 3               LOK
# 4               CEB
# ..              ...
# 294             GAL
# 295             THU
# 296             SER
# 297             LAU
# 298             LUG
#
# [299 rows x 6 columns]

# %%
team_att.drop(team_att[["id","team_fifa_api_id"]],axis =1, inplace = True)
team.drop(team[["id","team_fifa_api_id"]],axis = 1, inplace= True)

# %%
df_1 = pd.merge(left = team, right = team_att, how = "left", left_on = "team_api_id", right_on = "team_api_id")

# %%
df_1
# Out:
#       Unnamed: 0_x  team_api_id      team_long_name team_short_name  \
# 0                0         9987            KRC Genk             GEN
# 1                0         9987            KRC Genk             GEN
# 2                0         9987            KRC Genk             GEN
# 3                0         9987            KRC Genk             GEN
# 4                0         9987            KRC Genk             GEN
# ...            ...          ...                 ...             ...
# 1464           297         7730  FC Lausanne-Sports             LAU
# 1465           297         7730  FC Lausanne-Sports             LAU
# 1466           297         7730  FC Lausanne-Sports             LAU
# 1467           297         7730  FC Lausanne-Sports             LAU
# 1468           298         7896              Lugano             LUG
#
#       Unnamed: 0_y                 date  buildUpPlaySpeed  \
# 0            484.0  2010-02-22 00:00:00              45.0
# 1            485.0  2011-02-22 00:00:00              66.0
# 2            486.0  2012-02-22 00:00:00              53.0
# 3            487.0  2013-09-20 00:00:00              58.0
# 4            488.0  2014-09-19 00:00:00              58.0
# ...            ...                  ...               ...
# 1464         671.0  2010-02-22 00:00:00              30.0
# 1465         672.0  2012-02-22 00:00:00              37.0
# 1466         673.0  2013-09-20 00:00:00              51.0
# 1467         674.0  2014-09-19 00:00:00              37.0
# 1468           NaN                  NaN               NaN
#
#      buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0                 Balanced                   NaN                    Little
# 1                 Balanced                   NaN                    Little
# 2                 Balanced                   NaN                    Little
# 3                 Balanced                   NaN                    Little
# 4                 Balanced                  52.0                    Normal
# ...                    ...                   ...                       ...
# 1464                  Slow                   NaN                    Little
# 1465              Balanced                   NaN                    Little
# 1466              Balanced                   NaN                    Little
# 1467              Balanced                  55.0                    Normal
# 1468                   NaN                   NaN                       NaN
#
#       ...  chanceCreationShooting chanceCreationShootingClass  \
# 0     ...                    60.0                      Normal
# 1     ...                    51.0                      Normal
# 2     ...                    56.0                      Normal
# 3     ...                    56.0                      Normal
# 4     ...                    56.0                      Normal
# ...   ...                     ...                         ...
# 1464  ...                    60.0                      Normal
# 1465  ...                    48.0                      Normal
# 1466  ...                    48.0                      Normal
# 1467  ...                    52.0                      Normal
# 1468  ...                     NaN                         NaN
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised             70.0                 High
# 1                         Organised             48.0               Medium
# 2                         Organised             47.0               Medium
# 3                         Organised             47.0               Medium
# 4                         Organised             47.0               Medium
# ...                             ...              ...                  ...
# 1464                      Organised             55.0               Medium
# 1465                      Organised             43.0               Medium
# 1466                      Organised             43.0               Medium
# 1467                      Organised             46.0               Medium
# 1468                            NaN              NaN                  NaN
#
#       defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                  65.0                  Press              70.0
# 1                  47.0                  Press              54.0
# 2                  45.0                  Press              55.0
# 3                  45.0                  Press              55.0
# 4                  45.0                  Press              55.0
# ...                 ...                    ...               ...
# 1464               60.0                  Press              50.0
# 1465               43.0                  Press              55.0
# 1466               43.0                  Press              55.0
# 1467               44.0                  Press              55.0
# 1468                NaN                    NaN               NaN
#
#      defenceTeamWidthClass defenceDefenderLineClass
# 0                     Wide                    Cover
# 1                   Normal             Offside Trap
# 2                   Normal                    Cover
# 3                   Normal                    Cover
# 4                   Normal                    Cover
# ...                    ...                      ...
# 1464                Normal                    Cover
# 1465                Normal                    Cover
# 1466                Normal                    Cover
# 1467                Normal                    Cover
# 1468                   NaN                      NaN
#
# [1469 rows x 27 columns]

# %%
df_1.drop(df_1[["team_long_name","date"]], axis = 1, inplace = True)
df_1
# Out:
#       Unnamed: 0_x  team_api_id team_short_name  Unnamed: 0_y  \
# 0                0         9987             GEN         484.0
# 1                0         9987             GEN         485.0
# 2                0         9987             GEN         486.0
# 3                0         9987             GEN         487.0
# 4                0         9987             GEN         488.0
# ...            ...          ...             ...           ...
# 1464           297         7730             LAU         671.0
# 1465           297         7730             LAU         672.0
# 1466           297         7730             LAU         673.0
# 1467           297         7730             LAU         674.0
# 1468           298         7896             LUG           NaN
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                 45.0              Balanced                   NaN
# 1                 66.0              Balanced                   NaN
# 2                 53.0              Balanced                   NaN
# 3                 58.0              Balanced                   NaN
# 4                 58.0              Balanced                  52.0
# ...                ...                   ...                   ...
# 1464              30.0                  Slow                   NaN
# 1465              37.0              Balanced                   NaN
# 1466              51.0              Balanced                   NaN
# 1467              37.0              Balanced                  55.0
# 1468               NaN                   NaN                   NaN
#
#      buildUpPlayDribblingClass  buildUpPlayPassing buildUpPlayPassingClass  \
# 0                       Little                45.0                   Mixed
# 1                       Little                52.0                   Mixed
# 2                       Little                55.0                   Mixed
# 3                       Little                38.0                   Mixed
# 4                       Normal                38.0                   Mixed
# ...                        ...                 ...                     ...
# 1464                    Little                60.0                   Mixed
# 1465                    Little                49.0                   Mixed
# 1466                    Little                49.0                   Mixed
# 1467                    Normal                49.0                   Mixed
# 1468                       NaN                 NaN                     NaN
#
#       ... chanceCreationShooting  chanceCreationShootingClass  \
# 0     ...                   60.0                       Normal
# 1     ...                   51.0                       Normal
# 2     ...                   56.0                       Normal
# 3     ...                   56.0                       Normal
# 4     ...                   56.0                       Normal
# ...   ...                    ...                          ...
# 1464  ...                   60.0                       Normal
# 1465  ...                   48.0                       Normal
# 1466  ...                   48.0                       Normal
# 1467  ...                   52.0                       Normal
# 1468  ...                    NaN                          NaN
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised             70.0                 High
# 1                         Organised             48.0               Medium
# 2                         Organised             47.0               Medium
# 3                         Organised             47.0               Medium
# 4                         Organised             47.0               Medium
# ...                             ...              ...                  ...
# 1464                      Organised             55.0               Medium
# 1465                      Organised             43.0               Medium
# 1466                      Organised             43.0               Medium
# 1467                      Organised             46.0               Medium
# 1468                            NaN              NaN                  NaN
#
#       defenceAggression defenceAggressionClass defenceTeamWidth  \
# 0                  65.0                  Press             70.0
# 1                  47.0                  Press             54.0
# 2                  45.0                  Press             55.0
# 3                  45.0                  Press             55.0
# 4                  45.0                  Press             55.0
# ...                 ...                    ...              ...
# 1464               60.0                  Press             50.0
# 1465               43.0                  Press             55.0
# 1466               43.0                  Press             55.0
# 1467               44.0                  Press             55.0
# 1468                NaN                    NaN              NaN
#
#       defenceTeamWidthClass defenceDefenderLineClass
# 0                      Wide                    Cover
# 1                    Normal             Offside Trap
# 2                    Normal                    Cover
# 3                    Normal                    Cover
# 4                    Normal                    Cover
# ...                     ...                      ...
# 1464                 Normal                    Cover
# 1465                 Normal                    Cover
# 1466                 Normal                    Cover
# 1467                 Normal                    Cover
# 1468                    NaN                      NaN
#
# [1469 rows x 25 columns]

# %%
df_1.drop(df_1[['buildUpPlayDribbling']], axis = 1, inplace = True)

# %%
df = pd.merge(left = df, right = df_1, how = 'left', left_on = 'home_team_api_id', right_on = "team_api_id")
df.head(10)
# Out:
#    id_x                  league  country  id_y     season  match_api_id  \
# 0     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 1     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 2     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 3     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 4     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 5     1  Belgium Jupiler League  Belgium     1  2008/2009        492473
# 6     1  Belgium Jupiler League  Belgium     2  2008/2009        492474
# 7     1  Belgium Jupiler League  Belgium     2  2008/2009        492474
# 8     1  Belgium Jupiler League  Belgium     2  2008/2009        492474
# 9     1  Belgium Jupiler League  Belgium     2  2008/2009        492474
#
#    home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  ...  \
# 0              9987              9993               1               1  ...
# 1              9987              9993               1               1  ...
# 2              9987              9993               1               1  ...
# 3              9987              9993               1               1  ...
# 4              9987              9993               1               1  ...
# 5              9987              9993               1               1  ...
# 6             10000              9994               0               0  ...
# 7             10000              9994               0               0  ...
# 8             10000              9994               0               0  ...
# 9             10000              9994               0               0  ...
#
#    chanceCreationShooting  chanceCreationShootingClass  \
# 0                    60.0                       Normal
# 1                    51.0                       Normal
# 2                    56.0                       Normal
# 3                    56.0                       Normal
# 4                    56.0                       Normal
# 5                    56.0                       Normal
# 6                    50.0                       Normal
# 7                    53.0                       Normal
# 8                    50.0                       Normal
# 9                    32.0                       Little
#
#    chanceCreationPositioningClass  defencePressure  defencePressureClass  \
# 0                       Organised             70.0                  High
# 1                       Organised             48.0                Medium
# 2                       Organised             47.0                Medium
# 3                       Organised             47.0                Medium
# 4                       Organised             47.0                Medium
# 5                       Organised             36.0                Medium
# 6                       Organised             70.0                  High
# 7                       Organised             46.0                Medium
# 8                       Organised             44.0                Medium
# 9                       Organised             44.0                Medium
#
#   defenceAggression  defenceAggressionClass  defenceTeamWidth  \
# 0              65.0                   Press              70.0
# 1              47.0                   Press              54.0
# 2              45.0                   Press              55.0
# 3              45.0                   Press              55.0
# 4              45.0                   Press              55.0
# 5              57.0                   Press              70.0
# 6              60.0                   Press              70.0
# 7              48.0                   Press              53.0
# 8              55.0                   Press              53.0
# 9              58.0                   Press              37.0
#
#   defenceTeamWidthClass defenceDefenderLineClass
# 0                  Wide                    Cover
# 1                Normal             Offside Trap
# 2                Normal                    Cover
# 3                Normal                    Cover
# 4                Normal                    Cover
# 5                  Wide                    Cover
# 6                  Wide                    Cover
# 7                Normal                    Cover
# 8                Normal                    Cover
# 9                Normal                    Cover
#
# [10 rows x 37 columns]

# %%
df = df.loc[df['country'].isin(df["country"].value_counts().index.tolist()[:5])]

# %%
df_goals = df.groupby("country")
df_goals.mean()
# Out:
#             id_x          id_y  match_api_id  home_team_api_id  \
# country
# England   1729.0   3248.500000  1.178767e+06       9142.275000
# France    4769.0   6286.715915  1.169834e+06       9879.933911
# Germany   7809.0   9030.143292  1.187018e+06       9184.736780
# Italy    10257.0  11759.691751  1.233176e+06       9512.414230
# Spain    21518.0  23032.637807  1.211601e+06       9040.616205
#
#          away_team_api_id  home_team_goal  away_team_goal  home_player_X1  \
# country
# England       9142.275000        1.550987        1.159539        1.000000
# France        9830.500428        1.413355        1.030051        1.000000
# Germany       9179.564526        1.636414        1.271031        1.000000
# Italy        10331.056268        1.510803        1.105296        1.000342
# Spain         9031.444114        1.642352        1.131242        1.000000
#
#          home_player_X2  home_player_X3  ...  team_api_id  Unnamed: 0_y  \
# country                                  ...
# England        2.030263        4.029934  ...  9142.275000    790.706250
# France         2.038091        4.056395  ...  9879.933911    801.854821
# Germany        2.028617        4.034008  ...  9184.736780    634.944771
# Italy          2.283051        4.174106  ...  9512.414230    669.830340
# Spain          2.013635        4.012962  ...  9040.616205    745.479744
#
#          buildUpPlaySpeed  buildUpPlayPassing  chanceCreationPassing  \
# country
# England         56.271875           52.368750              50.980208
# France          53.267606           48.291441              51.323944
# Germany         56.969448           47.350176              55.119859
# Italy           55.732968           44.946639              53.679380
# Spain           47.052239           44.796375              53.848614
#
#          chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# country
# England               56.805208               52.204167        45.041667
# France                54.499458               53.404117        46.835320
# Germany               52.627497               54.893067        50.669800
# Italy                 52.946183               57.009578        42.794310
# Spain                 54.672708               55.557569        48.864606
#
#          defenceAggression  defenceTeamWidth
# country
# England          49.944792         51.048958
# France           49.071506         52.771398
# Germany          51.507638         51.367803
# Italy            51.100507         50.701043
# Spain            49.121535         55.990405
#
# [5 rows x 21 columns]

# %%
sns.barplot(x = "home_team_goal", y = 'country', data = df, palette = "Greens")

# %%
p_att = pd.read_csv('/content/drive/MyDrive/player_attributes.csv')
p_att.head(10)
# Out:
#    Unnamed: 0  id  player_fifa_api_id  player_api_id                 date  \
# 0           0   1              218353         505942  2016-02-18 00:00:00
# 1           1   2              218353         505942  2015-11-19 00:00:00
# 2           2   3              218353         505942  2015-09-21 00:00:00
# 3           3   4              218353         505942  2015-03-20 00:00:00
# 4           4   5              218353         505942  2007-02-22 00:00:00
# 5           5   6              189615         155782  2016-04-21 00:00:00
# 6           6   7              189615         155782  2016-04-07 00:00:00
# 7           7   8              189615         155782  2016-01-07 00:00:00
# 8           8   9              189615         155782  2015-12-24 00:00:00
# 9           9  10              189615         155782  2015-12-17 00:00:00
#
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
# 5            74.0       76.0           left                high
# 6            74.0       76.0           left                high
# 7            73.0       75.0           left                high
# 8            73.0       75.0           left                high
# 9            73.0       75.0           left                high
#
#   defensive_work_rate  ...  vision  penalties  marking  standing_tackle  \
# 0              medium  ...    54.0       48.0     65.0             69.0
# 1              medium  ...    54.0       48.0     65.0             69.0
# 2              medium  ...    54.0       48.0     65.0             66.0
# 3              medium  ...    53.0       47.0     62.0             63.0
# 4              medium  ...    53.0       47.0     62.0             63.0
# 5              medium  ...    66.0       59.0     76.0             75.0
# 6              medium  ...    66.0       59.0     76.0             75.0
# 7              medium  ...    65.0       59.0     76.0             75.0
# 8              medium  ...    65.0       59.0     76.0             75.0
# 9              medium  ...    65.0       59.0     76.0             75.0
#
#    sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0            69.0        6.0         11.0        10.0             8.0
# 1            69.0        6.0         11.0        10.0             8.0
# 2            69.0        6.0         11.0        10.0             8.0
# 3            66.0        5.0         10.0         9.0             7.0
# 4            66.0        5.0         10.0         9.0             7.0
# 5            78.0       14.0          7.0         9.0             9.0
# 6            78.0       14.0          7.0         9.0             9.0
# 7            78.0       14.0          7.0         9.0             9.0
# 8            78.0       14.0          7.0         9.0             9.0
# 9            78.0       14.0          7.0         9.0             9.0
#
#    gk_reflexes
# 0          8.0
# 1          8.0
# 2          8.0
# 3          7.0
# 4          7.0
# 5         12.0
# 6         12.0
# 7         12.0
# 8         12.0
# 9         12.0
#
# [10 rows x 43 columns]

# %%
p_att.columns
# Out:
# Index(['Unnamed: 0', 'id', 'player_fifa_api_id', 'player_api_id', 'date',
#        'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
p_att.drop(p_att[["date"]],axis = 1,inplace =True)

# %% [markdown]
# q. does preferred foot choice affect attacking work rate

# %%
p_att["attacking_work_rate"].unique()
# Out:
# array(['medium', 'high', nan, 'low', 'None', 'le', 'norm', 'stoc', 'y'],
#       dtype=object)

# %%
sns.countplot(data = p_att, x= "attacking_work_rate", hue = "preferred_foot", palette = "Greens") #effect of preferred foot actionon attacking work rate

# %% [markdown]
# q. does vision affect overall rating

# %%
grp = p_att.groupby("defensive_work_rate").mean()
sns.lineplot(data =  p_att,x = "vision", y = "overall_rating")

# %%
#sns.lineplot(data = p_att, y ='potential', x = 'defensive_work_rate')

# %% [markdown]
# q. does defensive work rate increase with increase in potential

# %%
sns.kdeplot( data = p_att, x= "potential", hue = "defensive_work_rate")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:154: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7f1dd5a748e0> has a label of '_0' which cannot be automatically added to the legend.
#   ax_obj.legend(handles, labels, title=self.variables["hue"], **legend_kws)

# %% [markdown]
# Q. how is goalkeeper's position related to attacking work rate

# %%
sns.kdeplot( data = p_att, x= "gk_positioning", hue = "attacking_work_rate")

# %% [markdown]
# q. does crossing affect finishing psoitively?

# %%
sns.lineplot(data = p_att, x = 'crossing', y= 'finishing' )

# %% [markdown]
# q. does crossing affect penalties?

# %%
sns.lineplot(data = p_att, x = 'crossing', y= 'penalties')
